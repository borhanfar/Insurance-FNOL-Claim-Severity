# %% [markdown]
# # Install

# %%
# %pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /local_disk0/.ephemeral_nfs/envs/pythonEnv-18848fef-a286-4e44-b166-e1f5e0c5084d/lib/python3.12/site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /local_disk0/.ephemeral_nfs/envs/pythonEnv-18848fef-a286-4e44-b166-e1f5e0c5084d/lib/python3.12/site-packages (from openpyxl) (2.0.0)
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
# %pip install xgboost
# Out:
# Requirement already satisfied: xgboost in /local_disk0/.ephemeral_nfs/envs/pythonEnv-18848fef-a286-4e44-b166-e1f5e0c5084d/lib/python3.12/site-packages (3.4.1)
# Requirement already satisfied: numpy in /databricks/python/lib/python3.12/site-packages (from xgboost) (2.1.3)
# Requirement already satisfied: scipy in /databricks/python/lib/python3.12/site-packages (from xgboost) (1.15.3)
# Requirement already satisfied: nvidia-nccl-cu13 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-18848fef-a286-4e44-b166-e1f5e0c5084d/lib/python3.12/site-packages (from xgboost) (2.31.2)
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
# %pip install "ray[tune]" hyperopt
# Out:
# Requirement already satisfied: hyperopt in /local_disk0/.ephemeral_nfs/envs/pythonEnv-18848fef-a286-4e44-b166-e1f5e0c5084d/lib/python3.12/site-packages (0.3.0)
# Requirement already satisfied: ray[tune] in /local_disk0/.ephemeral_nfs/envs/pythonEnv-18848fef-a286-4e44-b166-e1f5e0c5084d/lib/python3.12/site-packages (2.58.0)
# Requirement already satisfied: click>=7.0 in /databricks/python/lib/python3.12/site-packages (from ray[tune]) (8.1.8)
# Requirement already satisfied: filelock in /databricks/python/lib/python3.12/site-packages (from ray[tune]) (3.17.0)
# Requirement already satisfied: jsonschema in /databricks/python/lib/python3.12/site-packages (from ray[tune]) (4.23.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-18848fef-a286-4e44-b166-e1f5e0c5084d/lib/python3.12/site-packages (from ray[tune]) (1.2.2)
# Requirement already satisfied: packaging>=24.2 in /databricks/python/lib/python3.12/site-packages (from ray[tune]) (24.2)
# Requirement already satisfied: protobuf>=3.20.3 in /databricks/python/lib/python3.12/site-packages (from ray[tune]) (5.29.4)
# Requirement already satisfied: pyyaml in /databricks/python/lib/python3.12/site-packages (from ray[tune]) (6.0.2)
# Requirement already satisfied: requests in /databricks/python/lib/python3.12/site-packages (from ray[tune]) (2.32.3)
# Requirement already satisfied: pandas in /databricks/python/lib/python3.12/site-packages (from ray[tune]) (2.2.3)
# Requirement already satisfied: tensorboardX>=1.9 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-18848fef-a286-4e44-b166-e1f5e0c5084d/lib/python3.12/site-packages (from ray[tune]) (2.6.5)
# Requirement already satisfied: pyarrow>=17.0.0 in /databricks/python/lib/python3.12/site-packages (from ray[tune]) (21.0.0)
# Requirement already satisfied: fsspec in /databricks/python/lib/python3.12/site-packages (from ray[tune]) (2023.5.0)
# Requirement already satisfied: pydantic<3,>=2.5.0 in /databricks/python/lib/python3.12/site-packages (from ray[tune]) (2.10.6)
# Requirement already satisfied: cloudpickle in /databricks/python/lib/python3.12/site-packages (from hyperopt) (3.0.0)
# Requirement already satisfied: networkx>=2.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-18848fef-a286-4e44-b166-e1f5e0c5084d/lib/python3.12/site-packages (from hyperopt) (3.6.1)
# Requirement already satisfied: numpy>=1.17 in /databricks/python/lib/python3.12/site-packages (from hyperopt) (2.1.3)
# Requirement already satisfied: scipy>=1.5.0 in /databricks/python/lib/python3.12/site-packages (from hyperopt) (1.15.3)
# Requirement already satisfied: tqdm in /databricks/python/lib/python3.12/site-packages (from hyperopt) (4.67.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /databricks/python/lib/python3.12/site-packages (from pydantic<3,>=2.5.0->ray[tune]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /databricks/python/lib/python3.12/site-packages (from pydantic<3,>=2.5.0->ray[tune]) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /databricks/python/lib/python3.12/site-packages (from pydantic<3,>=2.5.0->ray[tune]) (4.12.2)
# Requirement already satisfied: attrs>=22.2.0 in /databricks/python/lib/python3.12/site-packages (from jsonschema->ray[tune]) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /databricks/python/lib/python3.12/site-packages (from jsonschema->ray[tune]) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /databricks/python/lib/python3.12/site-packages (from jsonschema->ray[tune]) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /databricks/python/lib/python3.12/site-packages (from jsonschema->ray[tune]) (0.22.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /databricks/python/lib/python3.12/site-packages (from pandas->ray[tune]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /databricks/python/lib/python3.12/site-packages (from pandas->ray[tune]) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /databricks/python/lib/python3.12/site-packages (from pandas->ray[tune]) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /databricks/python/lib/python3.12/site-packages (from requests->ray[tune]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python/lib/python3.12/site-packages (from requests->ray[tune]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /databricks/python/lib/python3.12/site-packages (from requests->ray[tune]) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /databricks/python/lib/python3.12/site-packages (from requests->ray[tune]) (2025.4.26)
# Requirement already satisfied: six>=1.5 in /databricks/python/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->ray[tune]) (1.17.0)
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %% [markdown]
# # Import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import mlflow
import mlflow.sklearn
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split, StratifiedKFold, KFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import TransformedTargetRegressor
from sklearn.metrics import (
    mean_squared_error,
    mean_absolute_error,
    mean_absolute_percentage_error,
    r2_score
)
import xgboost as xgb
# Ray Imports
import ray
from ray import tune
from ray.tune.search.hyperopt import HyperOptSearch

# %% [markdown]
# # Data

# %%
FNOL_pdf = pd.read_excel("/Volumes/workspace/default/hastings_direct/Data_Scientist_Interview_FNOL_Data.xlsx")
FNOL_pdf[['Incurred', 'Capped Incurred']] = FNOL_pdf[['Incurred', 'Capped Incurred']].round(0).astype(int)
FNOL_pdf = FNOL_pdf.drop(columns=["Claim Number","Loss_code", "Loss_description", "TP_type_insd_pass_front", 'TP_type_pass_multi'])
region_cols = [
    'TP_region_eastang', 'TP_region_eastmid', 'TP_region_london', 
    'TP_region_north', 'TP_region_northw', 'TP_region_outerldn', 
    'TP_region_scotland', 'TP_region_southe', 'TP_region_southw', 
    'TP_region_wales', 'TP_region_westmid', 'TP_region_yorkshire'
]

# 1. Clean all regional columns and convert string placeholders to clean integers
for col in region_cols:
    FNOL_pdf[col] = pd.to_numeric(FNOL_pdf[col].astype(str).replace(['-', 'n/k', '#', 'nan', 'None', ''], '0'), errors='coerce'
    ).fillna(0).astype(int)

# 2. Total third-party headcount aggregated across all regions
FNOL_pdf['Total_Regional_TP_Count'] = FNOL_pdf[region_cols].sum(axis=1)

# 3. Define tie-aware primary region extraction logic
def get_primary_region(row):
    # Filter active regions with headcounts > 0
    active_regions = row[region_cols][row[region_cols] > 0]
    
    if active_regions.empty:
        return 'None_Recorded'
    
    max_val = active_regions.max()
    top_regions = active_regions[active_regions == max_val].index.tolist()
    
    # If a single region clearly leads in headcount
    if len(top_regions) == 1:
        return top_regions[0].replace('TP_region_', '')
    
    # If there is a headcount tie between two or more top regions
    return 'Multi_Region_Tie'

# 4. Apply the tie-aware function row-by-row
FNOL_pdf['Primary_TP_Region'] = FNOL_pdf.apply(get_primary_region, axis=1)
FNOL_pdf = FNOL_pdf.drop(columns=region_cols)
# List of all 9 third-party type features
all_tp_type_cols = [
    'TP_type_insd_pass_back', 'TP_type_driver', 'TP_type_pass_back', 
    'TP_type_pass_front', 'TP_type_bike', 'TP_type_cyclist', 
    'TP_type_pedestrian', 'TP_type_other', 'TP_type_nk'
]

# 1. Clean all 9 columns (convert placeholders '-', 'n/k', '#' to 0)
for col in all_tp_type_cols:
    if col in FNOL_pdf.columns:
        FNOL_pdf[col] = pd.to_numeric(
            FNOL_pdf[col].astype(str).replace(['-', 'n/k', '#', 'nan', 'None', ''], '0'), 
            errors='coerce'
        ).fillna(0).astype(int)

# 2. Feature 1: Total Passenger Count (Front + Back Passengers)
FNOL_pdf['Total_TP_Passenger_Count'] = (
    FNOL_pdf['TP_type_pass_front'] + FNOL_pdf['TP_type_pass_back'] + FNOL_pdf['TP_type_insd_pass_back']
)

# 3. Feature 2: Vulnerable Road User Flag (Bikes, Cyclists, Pedestrians)
FNOL_pdf['Has_Vulnerable_Road_User'] = (
    (FNOL_pdf['TP_type_bike'] > 0) | 
    (FNOL_pdf['TP_type_cyclist'] > 0) | 
    (FNOL_pdf['TP_type_pedestrian'] > 0)
).astype(int)

# 4. Feature 3: Overall TP Count (Includes ALL 9 columns, including TP_type_nk)
existing_cols = [c for c in all_tp_type_cols if c in FNOL_pdf.columns]
FNOL_pdf['Total_TP_Type_Count'] = FNOL_pdf[existing_cols].sum(axis=1)
FNOL_pdf = FNOL_pdf.drop(columns=all_tp_type_cols)
# List of the 5 raw TP injury columns
injury_cols = ['TP_injury_whiplash', 'TP_injury_traumatic', 'TP_injury_fatality', 'TP_injury_unclear', 'TP_injury_nk']

# 1. Clean missing placeholders ('-', 'n/k', '#') across all 5 columns
for col in injury_cols:
    if col in FNOL_pdf.columns:
        FNOL_pdf[col] = pd.to_numeric(
            FNOL_pdf[col].astype(str).replace(['-', 'n/k', '#', 'nan', 'None', ''], '0'), 
            errors='coerce'
        ).fillna(0).astype(int)

# 2. Define the hierarchical severity function
def determine_max_injury_tier(row):
    # Tier 4: Fatality (Highest priority)
    if row.get('TP_injury_fatality', 0) > 0:
        return 4
    # Tier 3: Traumatic / Severe Body Injury
    elif row.get('TP_injury_traumatic', 0) > 0:
        return 3
    # Tier 2: Whiplash / Soft Tissue Injury
    elif row.get('TP_injury_whiplash', 0) > 0:
        return 2
    # Tier 1: Unclear or Not Known Injury details reported
    elif row.get('TP_injury_unclear', 0) > 0 or row.get('TP_injury_nk', 0) > 0:
        return 1
    # Tier 0: No Injury Recorded
    else:
        return 0

# 3. Apply the hierarchy row-by-row
FNOL_pdf['Max_Injury_Severity_Tier'] = FNOL_pdf.apply(determine_max_injury_tier, axis=1)

# 4. Optional: Also capture total count of injured third parties
FNOL_pdf['Total_Injured_TP_Count'] = FNOL_pdf[injury_cols].sum(axis=1)
FNOL_pdf = FNOL_pdf.drop(columns=injury_cols)
# 1. Identify your date column (replace 'date_of_loss' with your exact column name if different)
date_col = 'date_of_loss'

# 2. Convert to Pandas datetime format (handles formats like 'YYYY-MM-DD', 'DD/MM/YYYY', etc.)
FNOL_pdf[date_col] = pd.to_datetime(FNOL_pdf[date_col], errors='coerce')

# 3. Extract cyclical and temporal components
FNOL_pdf['loss_year'] = FNOL_pdf[date_col].dt.year
FNOL_pdf['loss_month'] = FNOL_pdf[date_col].dt.month
FNOL_pdf['loss_day_of_week'] = FNOL_pdf[date_col].dt.day_name()
FNOL_pdf = FNOL_pdf.drop(columns=date_col)
FNOL_pdf = FNOL_pdf.drop(columns="Incurred")
import numpy as np

# 1. Define your 10 categorical columns
cat_cols = [
    'Notifier', 'Location_of_incident', 'Weather_conditions', 'Vehicle_mobile', 'Main_driver', 
    'PH_considered_TP_at_fault', 'Primary_TP_Region', 'loss_day_of_week'
]

# 2. Define missing value placeholders and casing standardizations
missing_placeholders = ['N/K', 'n/k', 'NK', 'nk', '-', '#', 'n/a', 'N/A', 'None', 'nan', '', 'Not Applicable']
casing_fixes = {'other': 'OTHER', 'Other': 'OTHER', 'unknown': 'UNKNOWN', 'Unknown': 'UNKNOWN'}

# 3. Process all 10 columns in a single loop
for col in cat_cols:
    if col in FNOL_pdf.columns:
        FNOL_pdf[col] = (
            FNOL_pdf[col]
            .astype(str)                           # Ensure string type for reliable replacement
            .str.strip()                           # Strip leading/trailing whitespace
            .replace(missing_placeholders, np.nan) # Map unknown placeholders to true NaN
            .replace(casing_fixes)                # Standardize 'Other' casing
            .astype('category')                    # Convert to category for XGBoost
        )
FNOL_pdf = FNOL_pdf[(FNOL_pdf['Notification_period'] >= 0) & (FNOL_pdf['Capped Incurred'] >= 0)]
FNOL_pdf.head()
# Out:
#   Notifier  Notification_period  ...  loss_month loss_day_of_week
# 0       PH                   22  ...           4          Tuesday
# 1      CNF                    1  ...           4           Sunday
# 2      CNF                    5  ...           4         Thursday
# 3      CNF                    1  ...           5          Tuesday
# 4      CNF                    1  ...           6        Wednesday
#
# [5 rows x 23 columns]

# %%
FNOL_pdf
# Out:
#      Notifier  Notification_period  ...  loss_month loss_day_of_week
# 0          PH                   22  ...           4          Tuesday
# 1         CNF                    1  ...           4           Sunday
# 2         CNF                    5  ...           4         Thursday
# 3         CNF                    1  ...           5          Tuesday
# 4         CNF                    1  ...           6        Wednesday
# ...       ...                  ...  ...         ...              ...
# 7686    OTHER                    1  ...           6          Tuesday
# 7687    OTHER                    0  ...           6          Tuesday
# 7688    OTHER                    0  ...           6          Tuesday
# 7689    OTHER                    1  ...           6          Tuesday
# 7690    OTHER                    0  ...           6          Tuesday
#
# [7641 rows x 23 columns]

# %%
FNOL_pdf = FNOL_pdf[FNOL_pdf["Capped Incurred"] > 0].copy()

# Reset index after filtering
FNOL_pdf = FNOL_pdf.reset_index(drop=True)
FNOL_pdf
# Out:
#      Notifier  Notification_period  ...  loss_month loss_day_of_week
# 0         CNF                    1  ...           4           Sunday
# 1         CNF                    5  ...           4         Thursday
# 2         CNF                    1  ...           5          Tuesday
# 3         CNF                    1  ...           6        Wednesday
# 4          PH                   16  ...           6          Tuesday
# ...       ...                  ...  ...         ...              ...
# 5878    OTHER                    1  ...           6          Tuesday
# 5879    OTHER                    0  ...           6          Tuesday
# 5880    OTHER                    0  ...           6          Tuesday
# 5881    OTHER                    1  ...           6          Tuesday
# 5882    OTHER                    0  ...           6          Tuesday
#
# [5883 rows x 23 columns]

# %% [markdown]
# # Run the experiment with parameter tunning,choose best model and logged in mlflow

# %%
# 1. Define Feature Lists
categorical_features = [
    'Notifier', 'Location_of_incident', 'Weather_conditions', 'Vehicle_mobile',
    'Main_driver', 'PH_considered_TP_at_fault', 'Primary_TP_Region', 'loss_day_of_week',
]

numerical_features = [
    'Notification_period', 'Inception_to_loss', 'Time_hour',
    'Vechile_registration_present', 'Incident_details_present', 'Injury_details_present',
    'Total_Regional_TP_Count', 'Total_TP_Passenger_Count', 'Has_Vulnerable_Road_User',
    'Total_TP_Type_Count', 'Max_Injury_Severity_Tier', 'Total_Injured_TP_Count',
    'loss_year', 'loss_month',
]

all_features = categorical_features + numerical_features

# 2. Extract Features and Continuous Regression Target
X = FNOL_pdf[all_features].copy()
y = FNOL_pdf["Capped Incurred"].copy()  # Continuous target for Stage 2 Regression

# 3. Train / Test Split (80% Dev for 5-Fold CV, 20% Holdout Test)
X_dev, X_test, y_dev, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42
)

y_dev = pd.Series(y_dev).reset_index(drop=True)
y_test = pd.Series(y_test).reset_index(drop=True)

# 4. Pre-transform Data for Fast Ray Tune Execution
preprocessor = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(handle_unknown='ignore', sparse_output=False), categorical_features)
    ],
    remainder='passthrough'
)

X_dev_trans = preprocessor.fit_transform(X_dev)
X_test_trans = preprocessor.transform(X_test)

# Put datasets into Ray Object Store
X_dev_ref = ray.put(X_dev_trans)
y_dev_ref = ray.put(y_dev.values)
X_test_ref = ray.put(X_test_trans)
y_test_ref = ray.put(y_test.values)

# 5. Ray Tune Objective Function with Tweedie Loss 
def trainable_objective(config):
    X_d = ray.get(X_dev_ref)
    y_d = ray.get(y_dev_ref)
    X_te = ray.get(X_test_ref)
    y_te = ray.get(y_test_ref)

    kf = KFold(n_splits=5, shuffle=True, random_state=42)
    
    cv_tr_rmse, cv_val_rmse = [], []
    cv_tr_mae, cv_val_mae = [], []
    cv_tr_mape, cv_val_mape = [], []

    for train_idx, val_idx in kf.split(X_d, y_d):
        X_tr, X_va = X_d[train_idx], X_d[val_idx]
        y_tr, y_va = y_d[train_idx], y_d[val_idx]

        # XGBoost with Tweedie Loss Objective for Insurance Claims
        xgb_model = xgb.XGBRegressor(
            objective='reg:tweedie',
            tweedie_variance_power=config["tweedie_variance_power"],
            max_depth=int(config["max_depth"]),
            learning_rate=config["learning_rate"],
            n_estimators=int(config["n_estimators"]),
            subsample=config["subsample"],
            colsample_bytree=config["colsample_bytree"],
            reg_alpha=config["reg_alpha"],
            reg_lambda=config["reg_lambda"],
            missing=np.nan,
            random_state=42
        )

        
        model = TransformedTargetRegressor(
            regressor=xgb_model
        )

        model.fit(X_tr, y_tr)

        # Fold Train Metrics (Calculated on Original Dollar Scale)
        y_tr_pred = np.maximum(0, model.predict(X_tr))
        cv_tr_rmse.append(np.sqrt(mean_squared_error(y_tr, y_tr_pred)))
        cv_tr_mae.append(mean_absolute_error(y_tr, y_tr_pred))
        cv_tr_mape.append(mean_absolute_percentage_error(y_tr + 1e-5, y_tr_pred))

        # Fold Validation Metrics
        y_val_pred = np.maximum(0, model.predict(X_va))
        cv_val_rmse.append(np.sqrt(mean_squared_error(y_va, y_val_pred)))
        cv_val_mae.append(mean_absolute_error(y_va, y_val_pred))
        cv_val_mape.append(mean_absolute_percentage_error(y_va + 1e-5, y_val_pred))

    # Evaluate Holdout Test Set with Model Trained on Full Dev Set
    final_cv_xgb = xgb.XGBRegressor(
        objective='reg:tweedie',
        tweedie_variance_power=config["tweedie_variance_power"],
        max_depth=int(config["max_depth"]),
        learning_rate=config["learning_rate"],
        n_estimators=int(config["n_estimators"]),
        subsample=config["subsample"],
        colsample_bytree=config["colsample_bytree"],
        reg_alpha=config["reg_alpha"],
        reg_lambda=config["reg_lambda"],
        missing=np.nan,
        random_state=42
    )
    final_cv_model = TransformedTargetRegressor(
        regressor=final_cv_xgb
    )
    final_cv_model.fit(X_d, y_d)
    
    y_te_pred = np.maximum(0, final_cv_model.predict(X_te))
    te_rmse = np.sqrt(mean_squared_error(y_te, y_te_pred))
    te_mae = mean_absolute_error(y_te, y_te_pred)
    te_mape = mean_absolute_percentage_error(y_te + 1e-5, y_te_pred)

    tune.report(metrics={
        "train_rmse": np.mean(cv_tr_rmse),
        "train_mae": np.mean(cv_tr_mae),
        "train_mape": np.mean(cv_tr_mape),
        "val_rmse": np.mean(cv_val_rmse),
        "val_mae": np.mean(cv_val_mae),
        "val_mape": np.mean(cv_val_mape),
        "test_rmse": te_rmse,
        "test_mae": te_mae,
        "test_mape": te_mape,
        "rmse": np.mean(cv_val_rmse)  # Target metric for optimization
    })

# 6. Ray Tune Search Setup (Minimizing RMSE with Tweedie Parameters)
ray.init(ignore_reinit_error=True)

search_space = {
    "tweedie_variance_power": tune.choice([1.1, 1.3, 1.5, 1.7]),
    "max_depth": tune.choice([3, 4, 6]),
    "learning_rate": tune.choice([0.01, 0.03, 0.05]),
    "n_estimators": tune.choice([100, 200, 300]),
    "subsample": tune.choice([0.6, 0.7, 0.8]),
    "colsample_bytree": tune.choice([0.5, 0.6, 0.7]),
    "reg_alpha": tune.choice([0.5, 1.0, 5.0]),
    "reg_lambda": tune.choice([3.0, 5.0, 10.0])
}

hyperopt_search = HyperOptSearch(metric="rmse", mode="min")

tuner = tune.Tuner(
    trainable_objective,
    param_space=search_space,
    tune_config=tune.TuneConfig(
        search_alg=hyperopt_search,
        num_samples=20,
    )
)

results = tuner.fit()
best_result = results.get_best_result(metric="rmse", mode="min")
best_config = best_result.config

# 7. Generate Diagnostic Plots (RMSE, MAE, and MAPE) with Best Model Annotations
results_df = results.get_dataframe()
results_df = results_df.sort_values(by="val_rmse", ascending=True).reset_index(drop=True)

fig, axes = plt.subplots(1, 3, figsize=(22, 5.5))

metrics_to_plot = [
    ("train_rmse", "test_rmse", "RMSE ($)", "RMSE: 5-Fold Train vs. Holdout Test"),
    ("train_mae", "test_mae", "MAE ($)", "MAE: 5-Fold Train vs. Holdout Test"),
    ("train_mape", "test_mape", "MAPE (%)", "MAPE: 5-Fold Train vs. Holdout Test")
]

for idx, (tr_col, te_col, ylabel, title) in enumerate(metrics_to_plot):
    ax = axes[idx]
    
    # Scale MAPE for display if plotting percentages
    scale = 100 if "mape" in tr_col else 1.0
    
    ax.plot(results_df.index, results_df[tr_col] * scale, marker='o', label="5-Fold Train", color='navy')
    ax.plot(results_df.index, results_df[te_col] * scale, marker='^', label="Holdout Test", color='forestgreen')
    
    # Highlight Best Model (Rank 0) with Gold Star
    best_val = results_df.loc[0, te_col] * scale
    ax.scatter(0, best_val, color='gold', s=250, zorder=6, edgecolors='black', marker='*', label="Best Model (Logged)")
    
    ax.set_title(title, fontsize=11, fontweight='bold')
    ax.set_xlabel("Trial Rank (0 = Best Model)")
    ax.set_ylabel(ylabel)
    ax.grid(True, linestyle="--", alpha=0.6)
    ax.legend()

plt.tight_layout()
plot_filename = "cv_train_val_test_overfitting_tweedie_regression.png"
plt.savefig(plot_filename)
plt.show()

# 8. Re-train Final Pipeline on Full Development Set & Log to MLflow
mlflow.set_experiment("/Users/" + spark.sql("SELECT current_user()").collect()[0][0] + "/XGBoost_FNOL_two_stages_modeling")

with mlflow.start_run(run_name="XGBoost_Tweedie_Log_Capped_Incurred_Best_Model") as run:
    
    xgb_regressor = xgb.XGBRegressor(
        objective='reg:tweedie',
        tweedie_variance_power=best_config["tweedie_variance_power"],
        max_depth=int(best_config["max_depth"]),
        learning_rate=best_config["learning_rate"],
        n_estimators=int(best_config["n_estimators"]),
        subsample=best_config["subsample"],
        colsample_bytree=best_config["colsample_bytree"],
        reg_alpha=best_config["reg_alpha"],
        reg_lambda=best_config["reg_lambda"],
        missing=np.nan,
        random_state=42
    )

    best_pipeline = Pipeline(steps=[
        ('preprocessor', preprocessor),
        ('regressor', xgb_regressor)
    ])
    
    best_pipeline.fit(X_dev, y_dev)
    
    y_test_pred = np.maximum(0, best_pipeline.predict(X_test))
    
    # Calculate Final Holdout Regression Metrics
    final_rmse = np.sqrt(mean_squared_error(y_test, y_test_pred))
    final_mae = mean_absolute_error(y_test, y_test_pred)
    final_mape = mean_absolute_percentage_error(y_test + 1e-5, y_test_pred)
    final_r2 = r2_score(y_test, y_test_pred)
    
    mlflow.log_params(best_config)
    mlflow.log_metrics({
        "test_rmse": final_rmse,
        "test_mae": final_mae,
        "test_mape": final_mape,
        "test_r2_score": final_r2
    })
    
    mlflow.log_artifact(plot_filename)
    
    mlflow.sklearn.log_model(
        sk_model=best_pipeline,
        artifact_path="xgboost_fnol_pipeline_best",
        input_example=X_dev.iloc[:5]
    )

    print(f"\nLogged Best Model Run ID: {run.info.run_id}")
    print(
        f"Final Holdout Test Metrics -> "
        f"RMSE: ${final_rmse:.2f} | "
        f"MAE: ${final_mae:.2f} | "
        f"MAPE: {final_mape * 100:.2f}% | "
        f"R² Score: {final_r2:.4f}"
    )
# Out:
# 2026-09-12 22:17:59,879	INFO worker.py:1847 -- Calling ray.init() again after it has already been called.
# +----------------------------------------------------------------------------+
# | Configuration for experiment     trainable_objective_2026-09-12_22-17-59   |
# +----------------------------------------------------------------------------+
# | Search algorithm                 SearchGenerator                           |
# | Scheduler                        FIFOScheduler                             |
# | Number of trials                 20                                        |
# +----------------------------------------------------------------------------+
#
# View detailed results here: /home/spark-680056cb-3a23-4182-b851-a8/ray_results/trainable_objective_2026-09-12_22-17-59
# To visualize your results with TensorBoard, run: `tensorboard --logdir /local_disk0/tmp/ray/session_2026-09-12_20-50-42_943308_71/artifacts/2026-09-12_22-17-59/trainable_objective_2026-09-12_22-17-59/driver_artifacts`
#
# Trial status: 1 PENDING
# Current time: 2026-09-12 22:18:00. Total running time: 0s
# Logical resource usage: 1.0/4 CPUs, 0/0 GPUs
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                     status       ...ie_variance_power     max_depth     learning_rate     n_estimators     subsample     colsample_bytree     reg_alpha     reg_lambda |
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | trainable_objective_4cee5566   PENDING                       1.5             6              0.05              200           0.7                  0.7             5             10 |
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# Trial trainable_objective_4cee5566 started with configuration:
# +----------------------------------------------------+
# | Trial trainable_objective_4cee5566 config          |
# +----------------------------------------------------+
# | colsample_bytree                               0.7 |
# | learning_rate                                 0.05 |
# | max_depth                                        6 |
# | n_estimators                                   200 |
# | reg_alpha                                        5 |
# | reg_lambda                                      10 |
# | subsample                                      0.7 |
# | tweedie_variance_power                         1.5 |
# +----------------------------------------------------+
#
# Trial trainable_objective_4cee5566 completed after 1 iterations at 2026-09-12 22:18:03. Total running time: 4s
# +-------------------------------------------------------+
# | Trial trainable_objective_4cee5566 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              1.58315 |
# | time_total_s                                  1.58315 |
# | training_iteration                                  1 |
# | rmse                                          10509.7 |
# | test_mae                                      5238.57 |
# | test_mape                                     5.65828 |
# | test_rmse                                     10329.7 |
# | train_mae                                     4833.89 |
# | train_mape                                    2.92318 |
# | train_rmse                                    9399.32 |
# | val_mae                                       5604.11 |
# | val_mape                                      6.18758 |
# | val_rmse                                      10509.7 |
# +-------------------------------------------------------+
#
# Trial trainable_objective_d9d2b6a1 started with configuration:
# +----------------------------------------------------+
# | Trial trainable_objective_d9d2b6a1 config          |
# +----------------------------------------------------+
# | colsample_bytree                               0.5 |
# | learning_rate                                 0.01 |
# | max_depth                                        4 |
# | n_estimators                                   200 |
# | reg_alpha                                      0.5 |
# | reg_lambda                                      10 |
# | subsample                                      0.6 |
# | tweedie_variance_power                         1.7 |
# +----------------------------------------------------+
#
# Trial trainable_objective_d9d2b6a1 completed after 1 iterations at 2026-09-12 22:18:06. Total running time: 6s
# +-------------------------------------------------------+
# | Trial trainable_objective_d9d2b6a1 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              1.01103 |
# | time_total_s                                  1.01103 |
# | training_iteration                                  1 |
# | rmse                                            11534 |
# | test_mae                                      5733.14 |
# | test_mape                                     6.30097 |
# | test_rmse                                     11282.5 |
# | train_mae                                     6015.86 |
# | train_mape                                    5.20015 |
# | train_rmse                                    11377.2 |
# | val_mae                                       6139.77 |
# | val_mape                                       6.0629 |
# | val_rmse                                        11534 |
# +-------------------------------------------------------+
#
# Trial trainable_objective_79e1b4e3 started with configuration:
# +----------------------------------------------------+
# | Trial trainable_objective_79e1b4e3 config          |
# +----------------------------------------------------+
# | colsample_bytree                               0.5 |
# | learning_rate                                 0.03 |
# | max_depth                                        6 |
# | n_estimators                                   100 |
# | reg_alpha                                        1 |
# | reg_lambda                                      10 |
# | subsample                                      0.7 |
# | tweedie_variance_power                         1.5 |
# +----------------------------------------------------+
#
# Trial trainable_objective_79e1b4e3 completed after 1 iterations at 2026-09-12 22:18:08. Total running time: 8s
# +-------------------------------------------------------+
# | Trial trainable_objective_79e1b4e3 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              1.01075 |
# | time_total_s                                  1.01075 |
# | training_iteration                                  1 |
# | rmse                                          10924.6 |
# | test_mae                                      5400.26 |
# | test_mape                                      5.8547 |
# | test_rmse                                     10724.8 |
# | train_mae                                     5331.17 |
# | train_mape                                    3.62997 |
# | train_rmse                                    10270.9 |
# | val_mae                                        5798.2 |
# | val_mape                                      6.08946 |
# | val_rmse                                      10924.6 |
# +-------------------------------------------------------+
#
# Trial trainable_objective_9f594103 started with configuration:
# +----------------------------------------------------+
# | Trial trainable_objective_9f594103 config          |
# +----------------------------------------------------+
# | colsample_bytree                               0.7 |
# | learning_rate                                 0.03 |
# | max_depth                                        3 |
# | n_estimators                                   100 |
# | reg_alpha                                      0.5 |
# | reg_lambda                                       3 |
# | subsample                                      0.7 |
# | tweedie_variance_power                         1.7 |
# +----------------------------------------------------+
#
# Trial trainable_objective_9f594103 completed after 1 iterations at 2026-09-12 22:18:11. Total running time: 11s
# +-------------------------------------------------------+
# | Trial trainable_objective_9f594103 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              0.66271 |
# | time_total_s                                  0.66271 |
# | training_iteration                                  1 |
# | rmse                                          10869.6 |
# | test_mae                                      5412.25 |
# | test_mape                                     5.97137 |
# | test_rmse                                       10740 |
# | train_mae                                     5656.81 |
# | train_mape                                    5.44891 |
# | train_rmse                                    10711.3 |
# | val_mae                                          5777 |
# | val_mape                                      6.23588 |
# | val_rmse                                      10869.6 |
# +-------------------------------------------------------+
#
# Trial trainable_objective_cd45cbb8 started with configuration:
# +----------------------------------------------------+
# | Trial trainable_objective_cd45cbb8 config          |
# +----------------------------------------------------+
# | colsample_bytree                               0.5 |
# | learning_rate                                 0.05 |
# | max_depth                                        4 |
# | n_estimators                                   100 |
# | reg_alpha                                        5 |
# | reg_lambda                                       5 |
# | subsample                                      0.8 |
# | tweedie_variance_power                         1.7 |
# +----------------------------------------------------+
#
# Trial trainable_objective_cd45cbb8 completed after 1 iterations at 2026-09-12 22:18:13. Total running time: 13s
# +-------------------------------------------------------+
# | Trial trainable_objective_cd45cbb8 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              0.71803 |
# | time_total_s                                  0.71803 |
# | training_iteration                                  1 |
# | rmse                                          10718.2 |
# | test_mae                                      5277.12 |
# | test_mape                                     5.77763 |
# | test_rmse                                     10450.2 |
# | train_mae                                     5508.39 |
# | train_mape                                     5.1952 |
# | train_rmse                                    10467.9 |
# | val_mae                                       5680.66 |
# | val_mape                                      6.17321 |
# | val_rmse                                      10718.2 |
# +-------------------------------------------------------+
#
# Trial trainable_objective_11b1e3fb started with configuration:
# +----------------------------------------------------+
# | Trial trainable_objective_11b1e3fb config          |
# +----------------------------------------------------+
# | colsample_bytree                               0.7 |
# | learning_rate                                 0.01 |
# | max_depth                                        3 |
# | n_estimators                                   100 |
# | reg_alpha                                      0.5 |
# | reg_lambda                                       5 |
# | subsample                                      0.7 |
# | tweedie_variance_power                         1.1 |
# +----------------------------------------------------+
#
# Trial trainable_objective_11b1e3fb completed after 1 iterations at 2026-09-12 22:18:16. Total running time: 16s
# +-------------------------------------------------------+
# | Trial trainable_objective_11b1e3fb result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              0.46988 |
# | time_total_s                                  0.46988 |
# | training_iteration                                  1 |
# | rmse                                          12150.9 |
# | test_mae                                      6106.58 |
# | test_mape                                     6.94414 |
# | test_rmse                                     11935.9 |
# | train_mae                                     6422.92 |
# | train_mape                                    5.99491 |
# | train_rmse                                    12115.4 |
# | val_mae                                       6456.99 |
# | val_mape                                      6.23754 |
# | val_rmse                                      12150.9 |
# +-------------------------------------------------------+
#
# Trial trainable_objective_20188c47 started with configuration:
# +----------------------------------------------------+
# | Trial trainable_objective_20188c47 config          |
# +----------------------------------------------------+
# | colsample_bytree                               0.7 |
# | learning_rate                                 0.03 |
# | max_depth                                        4 |
# | n_estimators                                   100 |
# | reg_alpha                                        1 |
# | reg_lambda                                       5 |
# | subsample                                      0.7 |
# | tweedie_variance_power                         1.1 |
# +----------------------------------------------------+
#
# Trial trainable_objective_20188c47 completed after 1 iterations at 2026-09-12 22:18:18. Total running time: 18s
# +-------------------------------------------------------+
# | Trial trainable_objective_20188c47 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              0.55891 |
# | time_total_s                                  0.55891 |
# | training_iteration                                  1 |
# | rmse                                            10690 |
# | test_mae                                      5339.15 |
# | test_mape                                      5.9384 |
# | test_rmse                                     10602.9 |
# | train_mae                                     5421.89 |
# | train_mape                                    4.40019 |
# | train_rmse                                    10309.6 |
# | val_mae                                       5683.18 |
# | val_mape                                      6.03628 |
# | val_rmse                                        10690 |
# +-------------------------------------------------------+
#
# Trial trainable_objective_fdd66e9b started with configuration:
# +----------------------------------------------------+
# | Trial trainable_objective_fdd66e9b config          |
# +----------------------------------------------------+
# | colsample_bytree                               0.7 |
# | learning_rate                                 0.01 |
# | max_depth                                        6 |
# | n_estimators                                   100 |
# | reg_alpha                                      0.5 |
# | reg_lambda                                       3 |
# | subsample                                      0.7 |
# | tweedie_variance_power                         1.7 |
# +----------------------------------------------------+
#
# Trial trainable_objective_fdd66e9b completed after 1 iterations at 2026-09-12 22:18:21. Total running time: 21s
# +-------------------------------------------------------+
# | Trial trainable_objective_fdd66e9b result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              0.85417 |
# | time_total_s                                  0.85417 |
# | training_iteration                                  1 |
# | rmse                                          12244.2 |
# | test_mae                                      6118.48 |
# | test_mape                                     6.62912 |
# | test_rmse                                     12002.7 |
# | train_mae                                     6332.71 |
# | train_mape                                    4.62185 |
# | train_rmse                                    12084.3 |
# | val_mae                                       6485.09 |
# | val_mape                                      5.85021 |
# | val_rmse                                      12244.2 |
# +-------------------------------------------------------+
#
# Trial trainable_objective_8703abda started with configuration:
# +----------------------------------------------------+
# | Trial trainable_objective_8703abda config          |
# +----------------------------------------------------+
# | colsample_bytree                               0.5 |
# | learning_rate                                 0.03 |
# | max_depth                                        3 |
# | n_estimators                                   300 |
# | reg_alpha                                      0.5 |
# | reg_lambda                                       5 |
# | subsample                                      0.6 |
# | tweedie_variance_power                         1.5 |
# +----------------------------------------------------+
#
# Trial trainable_objective_8703abda completed after 1 iterations at 2026-09-12 22:18:24. Total running time: 24s
# +-------------------------------------------------------+
# | Trial trainable_objective_8703abda result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              1.15012 |
# | time_total_s                                  1.15012 |
# | training_iteration                                  1 |
# | rmse                                          10497.7 |
# | test_mae                                      5222.63 |
# | test_mape                                     5.82375 |
# | test_rmse                                     10329.2 |
# | train_mae                                     5290.36 |
# | train_mape                                    4.40698 |
# | train_rmse                                    10045.8 |
# | val_mae                                        5604.1 |
# | val_mape                                       6.2614 |
# | val_rmse                                      10497.7 |
# +-------------------------------------------------------+
#
# Trial trainable_objective_f1686eb1 started with configuration:
# +----------------------------------------------------+
# | Trial trainable_objective_f1686eb1 config          |
# +----------------------------------------------------+
# | colsample_bytree                               0.5 |
# | learning_rate                                 0.05 |
# | max_depth                                        6 |
# | n_estimators                                   100 |
# | reg_alpha                                        1 |
# | reg_lambda                                       5 |
# | subsample                                      0.8 |
# | tweedie_variance_power                         1.3 |
# +----------------------------------------------------+
#
# Trial trainable_objective_f1686eb1 completed after 1 iterations at 2026-09-12 22:18:26. Total running time: 26s
# +-------------------------------------------------------+
# | Trial trainable_objective_f1686eb1 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              0.82722 |
# | time_total_s                                  0.82722 |
# | training_iteration                                  1 |
# | rmse                                            10588 |
# | test_mae                                      5244.06 |
# | test_mape                                      5.7394 |
# | test_rmse                                     10344.1 |
# | train_mae                                     4654.87 |
# | train_mape                                    2.64188 |
# | train_rmse                                    9090.59 |
# | val_mae                                       5617.56 |
# | val_mape                                      5.90424 |
# | val_rmse                                        10588 |
# +-------------------------------------------------------+
#
# Trial trainable_objective_11187413 started with configuration:
# +----------------------------------------------------+
# | Trial trainable_objective_11187413 config          |
# +----------------------------------------------------+
# | colsample_bytree                               0.7 |
# | learning_rate                                 0.03 |
# | max_depth                                        6 |
# | n_estimators                                   100 |
# | reg_alpha                                      0.5 |
# | reg_lambda                                       3 |
# | subsample                                      0.8 |
# | tweedie_variance_power                         1.1 |
# +----------------------------------------------------+
#
# Trial trainable_objective_11187413 completed after 1 iterations at 2026-09-12 22:18:29. Total running time: 29s
# +-------------------------------------------------------+
# | Trial trainable_objective_11187413 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              0.87342 |
# | time_total_s                                  0.87342 |
# | training_iteration                                  1 |
# | rmse                                          10715.4 |
# | test_mae                                      5301.38 |
# | test_mape                                     5.81506 |
# | test_rmse                                     10569.5 |
# | train_mae                                     4914.26 |
# | train_mape                                    2.90259 |
# | train_rmse                                    9516.86 |
# | val_mae                                       5685.84 |
# | val_mape                                      5.89093 |
# | val_rmse                                      10715.4 |
# +-------------------------------------------------------+
#
# Trial status: 11 TERMINATED | 1 PENDING
# Current time: 2026-09-12 22:18:30. Total running time: 30s
# Logical resource usage: 1.0/4 CPUs, 0/0 GPUs
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                     status         ...ie_variance_power     max_depth     learning_rate     n_estimators     subsample     colsample_bytree     reg_alpha     reg_lambda     iter     total time (s)     train_rmse     train_mae     train_mape     val_rmse |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | trainable_objective_4cee5566   TERMINATED                      1.5             6              0.05              200           0.7                  0.7           5               10        1           1.58315         9399.32       4833.89        2.92318      10509.7 |
# | trainable_objective_d9d2b6a1   TERMINATED                      1.7             4              0.01              200           0.6                  0.5           0.5             10        1           1.01103        11377.2        6015.86        5.20015      11534   |
# | trainable_objective_79e1b4e3   TERMINATED                      1.5             6              0.03              100           0.7                  0.5           1               10        1           1.01075        10270.9        5331.17        3.62997      10924.6 |
# | trainable_objective_9f594103   TERMINATED                      1.7             3              0.03              100           0.7                  0.7           0.5              3        1           0.662709       10711.3        5656.81        5.44891      10869.6 |
# | trainable_objective_cd45cbb8   TERMINATED                      1.7             4              0.05              100           0.8                  0.5           5                5        1           0.718027       10467.9        5508.39        5.1952       10718.2 |
# | trainable_objective_11b1e3fb   TERMINATED                      1.1             3              0.01              100           0.7                  0.7           0.5              5        1           0.469877       12115.4        6422.92        5.99491      12150.9 |
# | trainable_objective_20188c47   TERMINATED                      1.1             4              0.03              100           0.7                  0.7           1                5        1           0.558906       10309.6        5421.89        4.40019      10690   |
# | trainable_objective_fdd66e9b   TERMINATED                      1.7             6              0.01              100           0.7                  0.7           0.5              3        1           0.854172       12084.3        6332.71        4.62185      12244.2 |
# | trainable_objective_8703abda   TERMINATED                      1.5             3              0.03              300           0.6                  0.5           0.5              5        1           1.15012        10045.8        5290.36        4.40698      10497.7 |
# | trainable_objective_f1686eb1   TERMINATED                      1.3             6              0.05              100           0.8                  0.5           1                5        1           0.827221        9090.59       4654.87        2.64188      10588   |
# | trainable_objective_11187413   TERMINATED                      1.1             6              0.03              100           0.8                  0.7           0.5              3        1           0.873423        9516.86       4914.26        2.90259      10715.4 |
# | trainable_objective_b88be372   PENDING                         1.1             6              0.01              100           0.7                  0.7           1                5                                                                                      |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# Trial trainable_objective_b88be372 started with configuration:
# +----------------------------------------------------+
# | Trial trainable_objective_b88be372 config          |
# +----------------------------------------------------+
# | colsample_bytree                               0.7 |
# | learning_rate                                 0.01 |
# | max_depth                                        6 |
# | n_estimators                                   100 |
# | reg_alpha                                        1 |
# | reg_lambda                                       5 |
# | subsample                                      0.7 |
# | tweedie_variance_power                         1.1 |
# +----------------------------------------------------+
#
# Trial trainable_objective_b88be372 completed after 1 iterations at 2026-09-12 22:18:31. Total running time: 31s
# +-------------------------------------------------------+
# | Trial trainable_objective_b88be372 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              0.85908 |
# | time_total_s                                  0.85908 |
# | training_iteration                                  1 |
# | rmse                                          12094.7 |
# | test_mae                                      6052.31 |
# | test_mape                                     6.76291 |
# | test_rmse                                       11867 |
# | train_mae                                     6229.54 |
# | train_mape                                    4.60727 |
# | train_rmse                                    11872.5 |
# | val_mae                                       6417.08 |
# | val_mape                                      5.97737 |
# | val_rmse                                      12094.7 |
# +-------------------------------------------------------+
#
# Trial trainable_objective_cff850ce started with configuration:
# +----------------------------------------------------+
# | Trial trainable_objective_cff850ce config          |
# +----------------------------------------------------+
# | colsample_bytree                               0.6 |
# | learning_rate                                 0.01 |
# | max_depth                                        4 |
# | n_estimators                                   100 |
# | reg_alpha                                      0.5 |
# | reg_lambda                                      10 |
# | subsample                                      0.8 |
# | tweedie_variance_power                         1.1 |
# +----------------------------------------------------+
#
# Trial trainable_objective_cff850ce completed after 1 iterations at 2026-09-12 22:18:33. Total running time: 34s
# +-------------------------------------------------------+
# | Trial trainable_objective_cff850ce result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              0.56065 |
# | time_total_s                                  0.56065 |
# | training_iteration                                  1 |
# | rmse                                          12151.7 |
# | test_mae                                      6109.55 |
# | test_mape                                     6.86886 |
# | test_rmse                                     11945.7 |
# | train_mae                                     6391.32 |
# | train_mape                                    5.69977 |
# | train_rmse                                    12076.7 |
# | val_mae                                        6456.3 |
# | val_mape                                      6.12205 |
# | val_rmse                                      12151.7 |
# +-------------------------------------------------------+
#
# Trial trainable_objective_d258f2b8 started with configuration:
# +----------------------------------------------------+
# | Trial trainable_objective_d258f2b8 config          |
# +----------------------------------------------------+
# | colsample_bytree                               0.7 |
# | learning_rate                                 0.03 |
# | max_depth                                        3 |
# | n_estimators                                   100 |
# | reg_alpha                                        1 |
# | reg_lambda                                      10 |
# | subsample                                      0.6 |
# | tweedie_variance_power                         1.3 |
# +----------------------------------------------------+
#
# Trial trainable_objective_d258f2b8 completed after 1 iterations at 2026-09-12 22:18:36. Total running time: 36s
# +-------------------------------------------------------+
# | Trial trainable_objective_d258f2b8 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              0.55443 |
# | time_total_s                                  0.55443 |
# | training_iteration                                  1 |
# | rmse                                          10828.2 |
# | test_mae                                      5394.04 |
# | test_mape                                     6.01431 |
# | test_rmse                                     10691.4 |
# | train_mae                                      5633.9 |
# | train_mape                                      5.558 |
# | train_rmse                                    10664.1 |
# | val_mae                                       5760.71 |
# | val_mape                                      6.28925 |
# | val_rmse                                      10828.2 |
# +-------------------------------------------------------+
#
# Trial trainable_objective_2b06e6d3 started with configuration:
# +----------------------------------------------------+
# | Trial trainable_objective_2b06e6d3 config          |
# +----------------------------------------------------+
# | colsample_bytree                               0.7 |
# | learning_rate                                 0.05 |
# | max_depth                                        4 |
# | n_estimators                                   300 |
# | reg_alpha                                        5 |
# | reg_lambda                                       5 |
# | subsample                                      0.6 |
# | tweedie_variance_power                         1.7 |
# +----------------------------------------------------+
#
# Trial trainable_objective_2b06e6d3 completed after 1 iterations at 2026-09-12 22:18:39. Total running time: 39s
# +-------------------------------------------------------+
# | Trial trainable_objective_2b06e6d3 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                               1.5024 |
# | time_total_s                                   1.5024 |
# | training_iteration                                  1 |
# | rmse                                          10559.7 |
# | test_mae                                      5255.29 |
# | test_mape                                     5.67494 |
# | test_rmse                                     10322.1 |
# | train_mae                                     5210.65 |
# | train_mape                                    4.06302 |
# | train_rmse                                    9944.39 |
# | val_mae                                       5626.56 |
# | val_mape                                      6.48746 |
# | val_rmse                                      10559.7 |
# +-------------------------------------------------------+
#
# Trial trainable_objective_cc54b2fb started with configuration:
# +----------------------------------------------------+
# | Trial trainable_objective_cc54b2fb config          |
# +----------------------------------------------------+
# | colsample_bytree                               0.7 |
# | learning_rate                                 0.03 |
# | max_depth                                        3 |
# | n_estimators                                   300 |
# | reg_alpha                                        5 |
# | reg_lambda                                       5 |
# | subsample                                      0.6 |
# | tweedie_variance_power                         1.3 |
# +----------------------------------------------------+
#
# Trial trainable_objective_cc54b2fb completed after 1 iterations at 2026-09-12 22:18:42. Total running time: 42s
# +-------------------------------------------------------+
# | Trial trainable_objective_cc54b2fb result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              1.27203 |
# | time_total_s                                  1.27203 |
# | training_iteration                                  1 |
# | rmse                                          10506.3 |
# | test_mae                                      5220.67 |
# | test_mape                                     5.86186 |
# | test_rmse                                     10262.1 |
# | train_mae                                     5327.77 |
# | train_mape                                    4.74998 |
# | train_rmse                                    10097.1 |
# | val_mae                                       5601.83 |
# | val_mape                                      6.33906 |
# | val_rmse                                      10506.3 |
# +-------------------------------------------------------+
#
# Trial trainable_objective_8f441a14 started with configuration:
# +----------------------------------------------------+
# | Trial trainable_objective_8f441a14 config          |
# +----------------------------------------------------+
# | colsample_bytree                               0.7 |
# | learning_rate                                 0.03 |
# | max_depth                                        4 |
# | n_estimators                                   100 |
# | reg_alpha                                        1 |
# | reg_lambda                                       3 |
# | subsample                                      0.7 |
# | tweedie_variance_power                         1.7 |
# +----------------------------------------------------+
#
# Trial trainable_objective_8f441a14 completed after 1 iterations at 2026-09-12 22:18:44. Total running time: 44s
# +-------------------------------------------------------+
# | Trial trainable_objective_8f441a14 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              0.59848 |
# | time_total_s                                  0.59848 |
# | training_iteration                                  1 |
# | rmse                                          10850.2 |
# | test_mae                                      5375.73 |
# | test_mape                                      5.8526 |
# | test_rmse                                     10670.5 |
# | train_mae                                     5539.13 |
# | train_mape                                    4.74132 |
# | train_rmse                                      10552 |
# | val_mae                                       5753.85 |
# | val_mape                                       6.0163 |
# | val_rmse                                      10850.2 |
# +-------------------------------------------------------+
#
# Trial trainable_objective_789d07b5 started with configuration:
# +----------------------------------------------------+
# | Trial trainable_objective_789d07b5 config          |
# +----------------------------------------------------+
# | colsample_bytree                               0.6 |
# | learning_rate                                 0.03 |
# | max_depth                                        3 |
# | n_estimators                                   300 |
# | reg_alpha                                        5 |
# | reg_lambda                                       3 |
# | subsample                                      0.8 |
# | tweedie_variance_power                         1.3 |
# +----------------------------------------------------+
#
# Trial trainable_objective_789d07b5 completed after 1 iterations at 2026-09-12 22:18:47. Total running time: 47s
# +-------------------------------------------------------+
# | Trial trainable_objective_789d07b5 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              1.20553 |
# | time_total_s                                  1.20553 |
# | training_iteration                                  1 |
# | rmse                                          10498.2 |
# | test_mae                                      5237.53 |
# | test_mape                                      5.8152 |
# | test_rmse                                     10349.4 |
# | train_mae                                     5333.04 |
# | train_mape                                    4.78642 |
# | train_rmse                                      10111 |
# | val_mae                                       5592.88 |
# | val_mape                                      6.12177 |
# | val_rmse                                      10498.2 |
# +-------------------------------------------------------+
#
# Trial trainable_objective_c9df826f started with configuration:
# +----------------------------------------------------+
# | Trial trainable_objective_c9df826f config          |
# +----------------------------------------------------+
# | colsample_bytree                               0.5 |
# | learning_rate                                 0.01 |
# | max_depth                                        3 |
# | n_estimators                                   300 |
# | reg_alpha                                      0.5 |
# | reg_lambda                                       5 |
# | subsample                                      0.8 |
# | tweedie_variance_power                         1.7 |
# +----------------------------------------------------+
#
# Trial trainable_objective_c9df826f completed after 1 iterations at 2026-09-12 22:18:49. Total running time: 49s
# +-------------------------------------------------------+
# | Trial trainable_objective_c9df826f result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              1.18694 |
# | time_total_s                                  1.18694 |
# | training_iteration                                  1 |
# | rmse                                          11014.8 |
# | test_mae                                      5488.37 |
# | test_mape                                     6.10773 |
# | test_rmse                                     10854.7 |
# | train_mae                                      5771.2 |
# | train_mape                                    5.46769 |
# | train_rmse                                      10869 |
# | val_mae                                       5877.85 |
# | val_mape                                      6.13868 |
# | val_rmse                                      11014.8 |
# +-------------------------------------------------------+
#
# Trial trainable_objective_a235e731 started with configuration:
# +----------------------------------------------------+
# | Trial trainable_objective_a235e731 config          |
# +----------------------------------------------------+
# | colsample_bytree                               0.6 |
# | learning_rate                                 0.03 |
# | max_depth                                        3 |
# | n_estimators                                   200 |
# | reg_alpha                                      0.5 |
# | reg_lambda                                      10 |
# | subsample                                      0.8 |
# | tweedie_variance_power                         1.1 |
# +----------------------------------------------------+
# 2026-09-12 22:18:51,710	INFO tune.py:1007 -- Wrote the latest version of all result files and experiment state to '/home/spark-680056cb-3a23-4182-b851-a8/ray_results/trainable_objective_2026-09-12_22-17-59' in 0.0351s.
# Trial trainable_objective_a235e731 completed after 1 iterations at 2026-09-12 22:18:51. Total running time: 51s
# +-------------------------------------------------------+
# | Trial trainable_objective_a235e731 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              0.74836 |
# | time_total_s                                  0.74836 |
# | training_iteration                                  1 |
# | rmse                                          10498.7 |
# | test_mae                                      5254.08 |
# | test_mape                                     5.91403 |
# | test_rmse                                     10389.9 |
# | train_mae                                     5347.77 |
# | train_mape                                     4.8309 |
# | train_rmse                                      10132 |
# | val_mae                                       5594.72 |
# | val_mape                                      6.22009 |
# | val_rmse                                      10498.7 |
# +-------------------------------------------------------+
#
# Trial status: 20 TERMINATED
# Current time: 2026-09-12 22:18:51. Total running time: 51s
# Logical resource usage: 1.0/4 CPUs, 0/0 GPUs
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                     status         ...ie_variance_power     max_depth     learning_rate     n_estimators     subsample     colsample_bytree     reg_alpha     reg_lambda     iter     total time (s)     train_rmse     train_mae     train_mape     val_rmse |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | trainable_objective_4cee5566   TERMINATED                      1.5             6              0.05              200           0.7                  0.7           5               10        1           1.58315         9399.32       4833.89        2.92318      10509.7 |
# | trainable_objective_d9d2b6a1   TERMINATED                      1.7             4              0.01              200           0.6                  0.5           0.5             10        1           1.01103        11377.2        6015.86        5.20015      11534   |
# | trainable_objective_79e1b4e3   TERMINATED                      1.5             6              0.03              100           0.7                  0.5           1               10        1           1.01075        10270.9        5331.17        3.62997      10924.6 |
# | trainable_objective_9f594103   TERMINATED                      1.7             3              0.03              100           0.7                  0.7           0.5              3        1           0.662709       10711.3        5656.81        5.44891      10869.6 |
# | trainable_objective_cd45cbb8   TERMINATED                      1.7             4              0.05              100           0.8                  0.5           5                5        1           0.718027       10467.9        5508.39        5.1952       10718.2 |
# | trainable_objective_11b1e3fb   TERMINATED                      1.1             3              0.01              100           0.7                  0.7           0.5              5        1           0.469877       12115.4        6422.92        5.99491      12150.9 |
# | trainable_objective_20188c47   TERMINATED                      1.1             4              0.03              100           0.7                  0.7           1                5        1           0.558906       10309.6        5421.89        4.40019      10690   |
# | trainable_objective_fdd66e9b   TERMINATED                      1.7             6              0.01              100           0.7                  0.7           0.5              3        1           0.854172       12084.3        6332.71        4.62185      12244.2 |
# | trainable_objective_8703abda   TERMINATED                      1.5             3              0.03              300           0.6                  0.5           0.5              5        1           1.15012        10045.8        5290.36        4.40698      10497.7 |
# | trainable_objective_f1686eb1   TERMINATED                      1.3             6              0.05              100           0.8                  0.5           1                5        1           0.827221        9090.59       4654.87        2.64188      10588   |
# | trainable_objective_11187413   TERMINATED                      1.1             6              0.03              100           0.8                  0.7           0.5              3        1           0.873423        9516.86       4914.26        2.90259      10715.4 |
# | trainable_objective_b88be372   TERMINATED                      1.1             6              0.01              100           0.7                  0.7           1                5        1           0.859083       11872.5        6229.54        4.60727      12094.7 |
# | trainable_objective_cff850ce   TERMINATED                      1.1             4              0.01              100           0.8                  0.6           0.5             10        1           0.560652       12076.7        6391.32        5.69977      12151.7 |
# | trainable_objective_d258f2b8   TERMINATED                      1.3             3              0.03              100           0.6                  0.7           1               10        1           0.554427       10664.1        5633.9         5.558        10828.2 |
# | trainable_objective_2b06e6d3   TERMINATED                      1.7             4              0.05              300           0.6                  0.7           5                5        1           1.5024          9944.39       5210.65        4.06302      10559.7 |
# | trainable_objective_cc54b2fb   TERMINATED                      1.3             3              0.03              300           0.6                  0.7           5                5        1           1.27203        10097.1        5327.77        4.74998      10506.3 |
# | trainable_objective_8f441a14   TERMINATED                      1.7             4              0.03              100           0.7                  0.7           1                3        1           0.598484       10552          5539.13        4.74132      10850.2 |
# | trainable_objective_789d07b5   TERMINATED                      1.3             3              0.03              300           0.8                  0.6           5                3        1           1.20553        10111          5333.04        4.78642      10498.2 |
# | trainable_objective_c9df826f   TERMINATED                      1.7             3              0.01              300           0.8                  0.5           0.5              5        1           1.18694        10869          5771.2         5.46769      11014.8 |
# | trainable_objective_a235e731   TERMINATED                      1.1             3              0.03              200           0.8                  0.6           0.5             10        1           0.748358       10132          5347.77        4.8309       10498.7 |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# 2026/09/12 22:18:54 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🔗 View Logged Model at: https://dbc-d7f1c5e3-bdfc.cloud.databricks.com/ml/experiments/1013088755239532/models/m-731e149e14d54374874f13f747cd774d?o=7474652645564939
# /databricks/python/lib/python3.12/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2026/09/12 22:18:54 WARNING mlflow.models.signature: Failed to infer the model signature from the input example. Reason: MlflowException("Failed to enforce schema of data '         Notifier Location_of_incident  ... loss_year loss_month\n5626        OTHER             Car Park  ...      2015          4\n2633           PH            Main Road  ...      2011          9\n2714        OTHER            Main Road  ...      2011         12\n3664  NamedDriver           Minor Road  ...      2013          7\n2244           PH            Main Road  ...      2010         11\n\n[5 rows x 22 columns]' with schema '['Notifier': string (required), 'Location_of_incident': string (required), 'Weather_conditions': string (optional), 'Vehicle_mobile': string (required), 'Main_driver': string (required), 'PH_considered_TP_at_fault': string (optional), 'Primary_TP_Region': string (required), 'loss_day_of_week': string (required), 'Notification_period': long (required), 'Inception_to_loss': long (required), 'Time_hour': long (required), 'Vechile_registration_present': long (required), 'Incident_details_present': long (required), 'Injury_details_present': long (required), 'Total_Regional_TP_Count': long (required), 'Total_TP_Passenger_Count': long (required), 'Has_Vulnerable_Road_User': long (required), 'Total_TP_Type_Count': long (required), 'Max_Injury_Severity_Tier': long (required), 'Total_Injured_TP_Count': long (required), 'loss_year': integer (required), 'loss_month': integer (required)]'. Error: Incompatible input types for column Notifier. Can not safely convert category to <U0."). To see the full traceback, set the logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)`.
# Logged Best Model Run ID: e9c2616fc8b6402081c13b6d99ce0304
# Final Holdout Test Metrics -> RMSE: $10329.16 | MAE: $5222.63 | MAPE: 582.37% | R² Score: 0.2531

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import mlflow
import mlflow.sklearn
from mlflow.tracking import MlflowClient

from sklearn.metrics import (
    mean_squared_error,
    mean_absolute_error,
    r2_score
)

# -------------------------------------------------------------------------
# 1. Load the Regression Model from MLflow using Run ID
# -------------------------------------------------------------------------
run_id = "e9c2616fc8b6402081c13b6d99ce0304"  # Replace with your actual Regression Run ID
artifact_path = (
    "xgboost_fnol_pipeline_best"  # Match the regression artifact path logged during training
)

model_uri = f"runs:/{run_id}/{artifact_path}"
print(f"Loading model from: {model_uri}")

# Load the full Scikit-Learn Pipeline (OneHotEncoder + XGBRegressor)
loaded_pipeline = mlflow.sklearn.load_model(model_uri)

# -------------------------------------------------------------------------
# 2. Predict on Data and Evaluate Regression Performance
# -------------------------------------------------------------------------
# Pass raw X_test directly - the pipeline handles feature transformations
y_pred = loaded_pipeline.predict(X_test)

# Calculate Regression Metrics
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("\n" + "=" * 40)
print("     REGRESSION MODEL PERFORMANCE EVALUATION")
print("=" * 40)
print(f"RMSE:         ${rmse:.2f}")
print(f"MAE:          ${mae:.2f}")
print(f"R² Score:     {r2:.4f}")

# -------------------------------------------------------------------------
# 3. Extract Feature Importances (Safely Unwraps Target Regressor)
# -------------------------------------------------------------------------
# Extract fitted steps from the pipeline
preprocessor = loaded_pipeline.named_steps["preprocessor"]
model_step = loaded_pipeline.named_steps["regressor"]

# Safely extract underlying model if wrapped in TransformedTargetRegressor
if hasattr(model_step, "regressor_"):
    xgb_model = model_step.regressor_
else:
    xgb_model = model_step

# Get encoded categorical feature names from OneHotEncoder
cat_encoder = preprocessor.named_transformers_["cat"]
encoded_cat_features = list(
    cat_encoder.get_feature_names_out(categorical_features)
)

# Combine with numerical features in exact pipeline processing order
feature_names = encoded_cat_features + numerical_features

# Extract gain-based feature importances from XGBRegressor
importances = xgb_model.feature_importances_

# Construct DataFrame
feature_imp_df = (
    pd.DataFrame({"Feature": feature_names, "Importance": importances})
    .sort_values(by="Importance", ascending=False)
    .reset_index(drop=True)
)

print("\n" + "=" * 40)
print("     TOP 15 FEATURE IMPORTANCES (REGRESSION)")
print("=" * 40)
print(feature_imp_df.head(15).to_string(index=False))

# -------------------------------------------------------------------------
# 4. Plot Feature Importances
# -------------------------------------------------------------------------
top_15_df = feature_imp_df.head(15)

plt.figure(figsize=(8, 4))
sns.barplot(
    data=top_15_df,
    x="Importance",
    y="Feature",
    hue="Feature",
    palette="viridis",
    legend=False,
)
plt.title("Top 15 Most Important Features (XGBoost Gain)", fontsize=13, fontweight="bold")
plt.xlabel("Relative Importance (Gain)", fontsize=11)
plt.ylabel("Feature Name", fontsize=11)
plt.grid(True, axis="x", linestyle="--", alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# Loading model from: runs:/e9c2616fc8b6402081c13b6d99ce0304/xgboost_fnol_pipeline_best
# Downloading artifacts:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading artifacts:   0%|          | 0/11 [00:00<?, ?it/s]
# ========================================
#      REGRESSION MODEL PERFORMANCE EVALUATION
# ========================================
# RMSE:         $10329.16
# MAE:          $5222.63
# R² Score:     0.2531
#
# ========================================
#      TOP 15 FEATURE IMPORTANCES (REGRESSION)
# ========================================
#                         Feature  Importance
#        Max_Injury_Severity_Tier    0.272822
#             Total_TP_Type_Count    0.066485
#         Total_Regional_TP_Count    0.056952
# Primary_TP_Region_None_Recorded    0.029915
#        Total_TP_Passenger_Count    0.024941
# Location_of_incident_Minor Road    0.023479
#          Injury_details_present    0.017663
#  Location_of_incident_Main Road    0.017506
#                Vehicle_mobile_N    0.016630
#          Total_Injured_TP_Count    0.016239
#                Vehicle_mobile_Y    0.015366
#        Primary_TP_Region_london    0.013519
#                       loss_year    0.013413
#       Weather_conditions_NORMAL    0.013144
#               Main_driver_OTHER    0.012452

# %% [markdown]
# # Performance the model on filterd data(only payout)

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Create temporary evaluation dataframe
eval_df = pd.DataFrame(
    {
        "True_Value": FNOL_pdf["Capped Incurred"],
        "Predicted_Value": loaded_pipeline.predict(FNOL_pdf[all_features]),
    }
)

eval_df["Abs_Difference"] = (
    eval_df["Predicted_Value"] - eval_df["True_Value"]
).abs()

# Set custom x-axis category names directly in qcut
custom_labels = ["< $5k", "$5k–$10k", "$10k–$20k", "$20k+"]
eval_df["Error_Tier"] = pd.qcut(
    eval_df["True_Value"], q=4, labels=custom_labels
)

# Group by tier
tier_summary = eval_df.groupby("Error_Tier", observed=False)[
    "Abs_Difference"
].mean()

# Plot
plt.figure(figsize=(8.5, 4.5))
ax = tier_summary.plot(kind="bar", color="#008080", edgecolor="black")

# Format bar top values
ax.bar_label(ax.containers[0], fmt="${:,.2f}", padding=4, fontweight="bold")
plt.ylim(0, tier_summary.max() * 1.15)

# Styling
plt.title(
    "Average Prediction Error ($) by Claim Value Range",
    fontsize=13,
    fontweight="bold",
)
plt.xlabel("Claim Value Range ($)", fontsize=11)
plt.ylabel("Average Error ($)", fontsize=11)
plt.xticks(rotation=0)
plt.grid(True, axis="y", linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd

# 1. Define custom monetary bands
bins = [0, 5000, 10000, 20000, np.inf]
labels = ["< $5k", "$5k–$10k", "$10k–$20k", "$20k+"]

# 2. Assign claim bands
FNOL_pdf["Claim_Band"] = pd.cut(
    FNOL_pdf["Capped Incurred"], bins=bins, labels=labels, include_lowest=True
)

# 3. Calculate count and percentage distribution
distribution_df = (
    FNOL_pdf["Claim_Band"]
    .value_counts(sort=False)
    .rename_axis("Claim Value Range")
    .reset_index(name="Claim Count")
)

distribution_df["Percentage (%)"] = (
    distribution_df["Claim Count"] / len(FNOL_pdf) * 100
).round(2)

print(distribution_df)
# Out:
#   Claim Value Range  Claim Count  Percentage (%)
# 0             < $5k         3707           63.01
# 1          $5k–$10k          722           12.27
# 2         $10k–$20k          715           12.15
# 3             $20k+          739           12.56

# %% [markdown]
# # Performance of the model on all data (include 1758 unseen records)

# %%
FNOL_pdf = pd.read_excel("/Volumes/workspace/default/hastings_direct/Data_Scientist_Interview_FNOL_Data.xlsx")
FNOL_pdf[['Incurred', 'Capped Incurred']] = FNOL_pdf[['Incurred', 'Capped Incurred']].round(0).astype(int)
FNOL_pdf = FNOL_pdf.drop(columns=["Claim Number","Loss_code", "Loss_description", "TP_type_insd_pass_front", 'TP_type_pass_multi'])
region_cols = [
    'TP_region_eastang', 'TP_region_eastmid', 'TP_region_london', 
    'TP_region_north', 'TP_region_northw', 'TP_region_outerldn', 
    'TP_region_scotland', 'TP_region_southe', 'TP_region_southw', 
    'TP_region_wales', 'TP_region_westmid', 'TP_region_yorkshire'
]

# 1. Clean all regional columns and convert string placeholders to clean integers
for col in region_cols:
    FNOL_pdf[col] = pd.to_numeric(FNOL_pdf[col].astype(str).replace(['-', 'n/k', '#', 'nan', 'None', ''], '0'), errors='coerce'
    ).fillna(0).astype(int)

# 2. Total third-party headcount aggregated across all regions
FNOL_pdf['Total_Regional_TP_Count'] = FNOL_pdf[region_cols].sum(axis=1)

# 3. Define tie-aware primary region extraction logic
def get_primary_region(row):
    # Filter active regions with headcounts > 0
    active_regions = row[region_cols][row[region_cols] > 0]
    
    if active_regions.empty:
        return 'None_Recorded'
    
    max_val = active_regions.max()
    top_regions = active_regions[active_regions == max_val].index.tolist()
    
    # If a single region clearly leads in headcount
    if len(top_regions) == 1:
        return top_regions[0].replace('TP_region_', '')
    
    # If there is a headcount tie between two or more top regions
    return 'Multi_Region_Tie'

# 4. Apply the tie-aware function row-by-row
FNOL_pdf['Primary_TP_Region'] = FNOL_pdf.apply(get_primary_region, axis=1)
FNOL_pdf = FNOL_pdf.drop(columns=region_cols)
# List of all 9 third-party type features
all_tp_type_cols = [
    'TP_type_insd_pass_back', 'TP_type_driver', 'TP_type_pass_back', 
    'TP_type_pass_front', 'TP_type_bike', 'TP_type_cyclist', 
    'TP_type_pedestrian', 'TP_type_other', 'TP_type_nk'
]

# 1. Clean all 9 columns (convert placeholders '-', 'n/k', '#' to 0)
for col in all_tp_type_cols:
    if col in FNOL_pdf.columns:
        FNOL_pdf[col] = pd.to_numeric(
            FNOL_pdf[col].astype(str).replace(['-', 'n/k', '#', 'nan', 'None', ''], '0'), 
            errors='coerce'
        ).fillna(0).astype(int)

# 2. Feature 1: Total Passenger Count (Front + Back Passengers)
FNOL_pdf['Total_TP_Passenger_Count'] = (
    FNOL_pdf['TP_type_pass_front'] + FNOL_pdf['TP_type_pass_back'] + FNOL_pdf['TP_type_insd_pass_back']
)

# 3. Feature 2: Vulnerable Road User Flag (Bikes, Cyclists, Pedestrians)
FNOL_pdf['Has_Vulnerable_Road_User'] = (
    (FNOL_pdf['TP_type_bike'] > 0) | 
    (FNOL_pdf['TP_type_cyclist'] > 0) | 
    (FNOL_pdf['TP_type_pedestrian'] > 0)
).astype(int)

# 4. Feature 3: Overall TP Count (Includes ALL 9 columns, including TP_type_nk)
existing_cols = [c for c in all_tp_type_cols if c in FNOL_pdf.columns]
FNOL_pdf['Total_TP_Type_Count'] = FNOL_pdf[existing_cols].sum(axis=1)
FNOL_pdf = FNOL_pdf.drop(columns=all_tp_type_cols)
# List of the 5 raw TP injury columns
injury_cols = ['TP_injury_whiplash', 'TP_injury_traumatic', 'TP_injury_fatality', 'TP_injury_unclear', 'TP_injury_nk']

# 1. Clean missing placeholders ('-', 'n/k', '#') across all 5 columns
for col in injury_cols:
    if col in FNOL_pdf.columns:
        FNOL_pdf[col] = pd.to_numeric(
            FNOL_pdf[col].astype(str).replace(['-', 'n/k', '#', 'nan', 'None', ''], '0'), 
            errors='coerce'
        ).fillna(0).astype(int)

# 2. Define the hierarchical severity function
def determine_max_injury_tier(row):
    # Tier 4: Fatality (Highest priority)
    if row.get('TP_injury_fatality', 0) > 0:
        return 4
    # Tier 3: Traumatic / Severe Body Injury
    elif row.get('TP_injury_traumatic', 0) > 0:
        return 3
    # Tier 2: Whiplash / Soft Tissue Injury
    elif row.get('TP_injury_whiplash', 0) > 0:
        return 2
    # Tier 1: Unclear or Not Known Injury details reported
    elif row.get('TP_injury_unclear', 0) > 0 or row.get('TP_injury_nk', 0) > 0:
        return 1
    # Tier 0: No Injury Recorded
    else:
        return 0

# 3. Apply the hierarchy row-by-row
FNOL_pdf['Max_Injury_Severity_Tier'] = FNOL_pdf.apply(determine_max_injury_tier, axis=1)

# 4. Optional: Also capture total count of injured third parties
FNOL_pdf['Total_Injured_TP_Count'] = FNOL_pdf[injury_cols].sum(axis=1)
FNOL_pdf = FNOL_pdf.drop(columns=injury_cols)
# 1. Identify your date column (replace 'date_of_loss' with your exact column name if different)
date_col = 'date_of_loss'

# 2. Convert to Pandas datetime format (handles formats like 'YYYY-MM-DD', 'DD/MM/YYYY', etc.)
FNOL_pdf[date_col] = pd.to_datetime(FNOL_pdf[date_col], errors='coerce')

# 3. Extract cyclical and temporal components
FNOL_pdf['loss_year'] = FNOL_pdf[date_col].dt.year
FNOL_pdf['loss_month'] = FNOL_pdf[date_col].dt.month
FNOL_pdf['loss_day_of_week'] = FNOL_pdf[date_col].dt.day_name()
FNOL_pdf = FNOL_pdf.drop(columns=date_col)
FNOL_pdf = FNOL_pdf.drop(columns="Incurred")
import numpy as np

# 1. Define your 10 categorical columns
cat_cols = [
    'Notifier', 'Location_of_incident', 'Weather_conditions', 'Vehicle_mobile', 'Main_driver', 
    'PH_considered_TP_at_fault', 'Primary_TP_Region', 'loss_day_of_week'
]

# 2. Define missing value placeholders and casing standardizations
missing_placeholders = ['N/K', 'n/k', 'NK', 'nk', '-', '#', 'n/a', 'N/A', 'None', 'nan', '', 'Not Applicable']
casing_fixes = {'other': 'OTHER', 'Other': 'OTHER', 'unknown': 'UNKNOWN', 'Unknown': 'UNKNOWN'}

# 3. Process all 10 columns in a single loop
for col in cat_cols:
    if col in FNOL_pdf.columns:
        FNOL_pdf[col] = (
            FNOL_pdf[col]
            .astype(str)                           # Ensure string type for reliable replacement
            .str.strip()                           # Strip leading/trailing whitespace
            .replace(missing_placeholders, np.nan) # Map unknown placeholders to true NaN
            .replace(casing_fixes)                # Standardize 'Other' casing
            .astype('category')                    # Convert to category for XGBoost
        )
FNOL_pdf = FNOL_pdf[(FNOL_pdf['Notification_period'] >= 0) & (FNOL_pdf['Capped Incurred'] >= 0)]
FNOL_pdf.head()


import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import mlflow
import mlflow.sklearn

from sklearn.metrics import (
    mean_squared_error,
    mean_absolute_error,
    mean_absolute_percentage_error,
    r2_score
)
from sklearn.model_selection import train_test_split, KFold
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import TransformedTargetRegressor
import xgboost as xgb

# Ray Imports
import ray
from ray import tune
from ray.tune.search.hyperopt import HyperOptSearch

# 1. Define Feature Lists
categorical_features = [
    'Notifier', 'Location_of_incident', 'Weather_conditions', 'Vehicle_mobile',
    'Main_driver', 'PH_considered_TP_at_fault', 'Primary_TP_Region', 'loss_day_of_week',
]

numerical_features = [
    'Notification_period', 'Inception_to_loss', 'Time_hour',
    'Vechile_registration_present', 'Incident_details_present', 'Injury_details_present',
    'Total_Regional_TP_Count', 'Total_TP_Passenger_Count', 'Has_Vulnerable_Road_User',
    'Total_TP_Type_Count', 'Max_Injury_Severity_Tier', 'Total_Injured_TP_Count',
    'loss_year', 'loss_month',
]

all_features = categorical_features + numerical_features

# 2. Extract Features and Continuous Regression Target
X = FNOL_pdf[all_features].copy()
y = FNOL_pdf["Capped Incurred"].copy()  # Continuous target for Stage 2 Regression

# 3. Train / Test Split (80% Dev for 5-Fold CV, 20% Holdout Test)
X_dev, X_test, y_dev, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42
)

# -------------------------------------------------------------------------
# 1. Load the Regression Model from MLflow using Run ID
# -------------------------------------------------------------------------
run_id = "e9c2616fc8b6402081c13b6d99ce0304"  # Replace with your actual Regression Run ID
artifact_path = (
    "xgboost_fnol_pipeline_best"  # Match the regression artifact path logged during training
)

model_uri = f"runs:/{run_id}/{artifact_path}"
print(f"Loading model from: {model_uri}")

# Load the full Scikit-Learn Pipeline (OneHotEncoder + XGBRegressor)
loaded_pipeline = mlflow.sklearn.load_model(model_uri)


import matplotlib.pyplot as plt
import pandas as pd

# Create temporary evaluation dataframe
eval_df = pd.DataFrame(
    {
        "True_Value": FNOL_pdf["Capped Incurred"],
        "Predicted_Value": loaded_pipeline.predict(FNOL_pdf[all_features]),
    }
)

eval_df["Abs_Difference"] = (
    eval_df["Predicted_Value"] - eval_df["True_Value"]
).abs()

# Set custom x-axis category names directly in qcut
custom_labels = ["< $5k", "$5k–$10k", "$10k–$20k", "$20k+"]
eval_df["Error_Tier"] = pd.qcut(
    eval_df["True_Value"], q=4, labels=custom_labels
)

# Group by tier
tier_summary = eval_df.groupby("Error_Tier", observed=False)[
    "Abs_Difference"
].mean()

# Plot
plt.figure(figsize=(8.5, 4.5))
ax = tier_summary.plot(kind="bar", color="#008080", edgecolor="black")

# Format bar top values
ax.bar_label(ax.containers[0], fmt="${:,.2f}", padding=4, fontweight="bold")
plt.ylim(0, tier_summary.max() * 1.15)

# Styling
plt.title(
    "Average Prediction Error ($) by Claim Value Range",
    fontsize=13,
    fontweight="bold",
)
plt.xlabel("Claim Value Range ($)", fontsize=11)
plt.ylabel("Average Error ($)", fontsize=11)
plt.xticks(rotation=0)
plt.grid(True, axis="y", linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# Loading model from: runs:/e9c2616fc8b6402081c13b6d99ce0304/xgboost_fnol_pipeline_best
# Downloading artifacts:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading artifacts:   0%|          | 0/11 [00:00<?, ?it/s]

# %%
# 1. Define custom monetary bands
bins = [0, 5000, 10000, 20000, np.inf]
labels = ["< $5k", "$5k–$10k", "$10k–$20k", "$20k+"]

# 2. Assign claim bands
FNOL_pdf["Claim_Band"] = pd.cut(
    FNOL_pdf["Capped Incurred"], bins=bins, labels=labels, include_lowest=True
)

# 3. Calculate count and percentage distribution
distribution_df = (
    FNOL_pdf["Claim_Band"]
    .value_counts(sort=False)
    .rename_axis("Claim Value Range")
    .reset_index(name="Claim Count")
)

distribution_df["Percentage (%)"] = (
    distribution_df["Claim Count"] / len(FNOL_pdf) * 100
).round(2)

print(distribution_df)
# Out:
#   Claim Value Range  Claim Count  Percentage (%)
# 0             < $5k         5465           71.52
# 1          $5k–$10k          722            9.45
# 2         $10k–$20k          715            9.36
# 3             $20k+          739            9.67
